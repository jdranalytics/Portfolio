# %% [markdown]
# # Predicción de Cantidades Vendidas por Grupo (Prophet)
#
# Este notebook replica el flujo de predicción de cantidades vendidas usando Prophet, pero ahora genera un modelo y predicción por cada grupo de `REGION_CATEGORIA_PRODUCTO`. Se exportan todas las predicciones y métricas a Snowflake, y se visualiza solo el 10% de los grupos seleccionados al azar.

# %% [markdown]
# ## 1. Importar Librerías y Configuración
#
# Importamos las librerías necesarias y configuramos logging y warnings.

# %%
import pandas as pd
import numpy as np
import snowflake.connector
import logging
from datetime import datetime
import os
from prophet import Prophet
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler
import plotly.graph_objects as go
import plotly.subplots as sp
from tqdm import tqdm
import random
import warnings

# Suppress warnings
warnings.filterwarnings("ignore")

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[logging.StreamHandler()]
)

# Suppress Prophet and related loggers
for logger_name in ['prophet', 'fbprophet', 'cmdstanpy']:
    logging.getLogger(logger_name).setLevel(logging.CRITICAL)

# %% [markdown]
# ## 2. Carga de Datos desde Snowflake
#
# Definimos funciones para conectar y cargar los dataframes históricos y de escenarios desde Snowflake, sin filtrar por REGION_CATEGORIA_PRODUCTO.

# %%
def get_snowflake_connection():
    try:
        conn = snowflake.connector.connect(
            user='XXXXXXXXXXXXXXXXX',  
            password='XXXXXXXXXXXXXXX',  
            account='XXXXXXXXXXXXXXXX', 
            warehouse='XXXXXXXXXXXXXXX', 
            database='XXXXXXXXXXXXXXX',
            schema='BEBIDAS_ANALYTICS'
        )
        logging.info("Conexión a Snowflake exitosa")
        return conn
    except Exception as e:
        logging.error(f"Error de conexión a Snowflake: {e}")
        raise

def load_snowflake_views():
    required_cols = ['MES', 'REGION_CATEGORIA_PRODUCTO',  'AVG_PRECIO_LISTA', 'AVG_DESC_PORCENTAJE']
    conn = get_snowflake_connection()
    try:
        df_hist = pd.read_sql("SELECT * FROM VW_VENTAS_HISTORICO_M3", conn)
        df_fcst1 = pd.read_sql("SELECT * FROM VW_VENTAS_FCST_FEATURES_1", conn)
        df_fcst2 = pd.read_sql("SELECT * FROM VW_VENTAS_FCST_FEATURES_2", conn)
        
        # Validate columns
        for df, name in [(df_hist, 'Histórico'), (df_fcst1, 'Escenario 1'), (df_fcst2, 'Escenario 2')]:
            missing_cols = [col for col in required_cols if col not in df.columns]
            if missing_cols:
                raise ValueError(f"Missing columns in {name}: {missing_cols}")
        
        logging.info(f"Histórico: {len(df_hist)} registros, Escenario 1: {len(df_fcst1)}, Escenario 2: {len(df_fcst2)}")
        return df_hist, df_fcst1, df_fcst2
    finally:
        conn.close()

# Load data
df_hist, df_fcst1, df_fcst2 = load_snowflake_views()
print(f"Histórico: {df_hist.shape}, Escenario 1: {df_fcst1.shape}, Escenario 2: {df_fcst2.shape}")
# Out:
# 2025-06-29 01:23:21,813 - INFO - Snowflake Connector for Python Version: 3.15.0, Python Version: 3.10.11, Platform: Windows-10-10.0.19045-SP0
# 2025-06-29 01:23:21,815 - INFO - Connecting to GLOBAL Snowflake domain
# 2025-06-29 01:23:21,815 - INFO - Connecting to GLOBAL Snowflake domain
# 2025-06-29 01:23:22,613 - INFO - Conexión a Snowflake exitosa
# 2025-06-29 01:23:22,613 - INFO - Conexión a Snowflake exitosa
# 2025-06-29 01:23:28,333 - INFO - Histórico: 3703 registros, Escenario 1: 1560, Escenario 2: 1560
# 2025-06-29 01:23:28,333 - INFO - Histórico: 3703 registros, Escenario 1: 1560, Escenario 2: 1560
# Histórico: (3703, 6), Escenario 1: (1560, 5), Escenario 2: (1560, 5)

# %% [markdown]
# ## 3. Preparación de Datos para Prophet por Grupo
#
# Identificamos todos los valores únicos de `REGION_CATEGORIA_PRODUCTO`. Para cada grupo, preparamos los dataframes históricos y de escenarios, escalando variables y agregando columnas requeridas para Prophet.

# %%
# Exogenous variables
exog_vars = ['AVG_PRECIO_LISTA', 'AVG_DESC_PORCENTAJE']

# Identify unique groups
grupos = df_hist['REGION_CATEGORIA_PRODUCTO'].unique()
print(f"Total de grupos: {len(grupos)}")

# Initialize result and metrics lists
resultados_todos = []
metricas_todos = []
# Out:
# Total de grupos: 130

# %% [markdown]
# ## 4. Entrenamiento y Predicción por Grupo
#
# Iteramos sobre cada grupo. Para cada uno, entrenamos un modelo Prophet con variables exógenas, generamos predicciones para ambos escenarios, desescalamos resultados y calculamos intervalos de confianza.

# %%
from tqdm import tqdm

# Clear lists to avoid duplicates
resultados_todos = []
metricas_todos = []

for grupo in tqdm(grupos, desc="Procesando grupos Prophet"):
    # Filter data by group
    hist_g = df_hist[df_hist['REGION_CATEGORIA_PRODUCTO'] == grupo].copy()
    fcst1_g = df_fcst1[df_fcst1['REGION_CATEGORIA_PRODUCTO'] == grupo].copy()
    fcst2_g = df_fcst2[df_fcst2['REGION_CATEGORIA_PRODUCTO'] == grupo].copy()
    
    # Skip groups with insufficient data
    if len(hist_g) < 12 or len(fcst1_g) == 0 or len(fcst2_g) == 0:
        logging.warning(f"Grupo {grupo} omitido: pocos datos (Hist: {len(hist_g)}, Fcst1: {len(fcst1_g)}, Fcst2: {len(fcst2_g)})")
        continue
    
    # Prepare columns
    hist_g['ds'] = pd.to_datetime(hist_g['MES'])
    hist_g['y'] = hist_g['M3_VENDIDOS']
    fcst1_g['ds'] = pd.to_datetime(fcst1_g['MES'])
    fcst2_g['ds'] = pd.to_datetime(fcst2_g['MES'])
    
    # Scale variables
    target_scaler = StandardScaler()
    exog_scaler = StandardScaler()
    hist_g['y_scaled'] = target_scaler.fit_transform(hist_g[['y']]).flatten()
    scaled_exog = exog_scaler.fit_transform(hist_g[exog_vars])
    for idx, var in enumerate(exog_vars):
        hist_g[f'{var}_scaled'] = scaled_exog[:, idx]
    
    def scale_exog(df):
        scaled = exog_scaler.transform(df[exog_vars])
        for idx, var in enumerate(exog_vars):
            df[f'{var}_scaled'] = scaled[:, idx]
        return df
    
    fcst1_g = scale_exog(fcst1_g)
    fcst2_g = scale_exog(fcst2_g)
    exog_vars_scaled = [f'{var}_scaled' for var in exog_vars]
    
    # Train Prophet model
    m = Prophet(yearly_seasonality=True, weekly_seasonality=False, daily_seasonality=False)
    for var in exog_vars_scaled:
        m.add_regressor(var)
    m.fit(hist_g[['ds', 'y_scaled'] + exog_vars_scaled].rename(columns={'y_scaled': 'y'}))
    
    # Prepare future dataframes
    def prepare_future_scaled(df_fcst):
        return df_fcst[['ds'] + exog_vars_scaled].copy()
    
    future1 = prepare_future_scaled(fcst1_g)
    future2 = prepare_future_scaled(fcst2_g)
    
    # Generate predictions
    forecast1 = m.predict(future1)
    forecast2 = m.predict(future2)
    
    # Inverse scale predictions
    fcst1_g['CANTIDAD_VENDIDA_PRED'] = target_scaler.inverse_transform(forecast1[['yhat']]).flatten()
    fcst1_g['IC_95_LOWER'] = target_scaler.inverse_transform(forecast1[['yhat_lower']]).flatten()
    fcst1_g['IC_95_UPPER'] = target_scaler.inverse_transform(forecast1[['yhat_upper']]).flatten()
    fcst2_g['CANTIDAD_VENDIDA_PRED'] = target_scaler.inverse_transform(forecast2[['yhat']]).flatten()
    fcst2_g['IC_95_LOWER'] = target_scaler.inverse_transform(forecast2[['yhat_lower']]).flatten()
    fcst2_g['IC_95_UPPER'] = target_scaler.inverse_transform(forecast2[['yhat_upper']]).flatten()
    
    # Add metadata
    hist_g['TIPO'] = 'HISTÓRICO'
    hist_g['IC_95_LOWER'] = np.nan
    hist_g['IC_95_UPPER'] = np.nan
    hist_g['DIF_PCT'] = hist_g['y'].pct_change() * 100
    fcst1_g['TIPO'] = 'ESCENARIO 1'
    fcst2_g['TIPO'] = 'ESCENARIO 2'
    
    # Calculate percentage differences
    last_hist = hist_g['y'].iloc[-1]
    def calc_diff(df, col, first_ref=None):
        diffs = df[col].pct_change() * 100
        if first_ref is not None and len(diffs) > 0:
            diffs.iloc[0] = 100 * (df[col].iloc[0] - first_ref) / ((abs(df[col].iloc[0]) + abs(first_ref)) / 2)
        return diffs
    
    fcst1_g['DIF_PCT'] = calc_diff(fcst1_g, 'CANTIDAD_VENDIDA_PRED', first_ref=last_hist)
    fcst2_g['DIF_PCT'] = calc_diff(fcst2_g, 'CANTIDAD_VENDIDA_PRED', first_ref=last_hist)
    
    # Consolidate results
    hist_tabla = hist_g[['ds', 'REGION_CATEGORIA_PRODUCTO', 'y', 'TIPO', 'IC_95_LOWER', 'IC_95_UPPER', 'DIF_PCT']].rename(columns={'y': 'M3_PRODUCTO'})
    sc1 = fcst1_g[['ds', 'REGION_CATEGORIA_PRODUCTO', 'CANTIDAD_VENDIDA_PRED', 'TIPO', 'IC_95_LOWER', 'IC_95_UPPER', 'DIF_PCT']].rename(columns={'CANTIDAD_VENDIDA_PRED': 'M3_PRODUCTO'})
    sc2 = fcst2_g[['ds', 'REGION_CATEGORIA_PRODUCTO', 'CANTIDAD_VENDIDA_PRED', 'TIPO', 'IC_95_LOWER', 'IC_95_UPPER', 'DIF_PCT']].rename(columns={'CANTIDAD_VENDIDA_PRED': 'M3_PRODUCTO'})
    
    # Combine and append results
    resultados_todos.append(pd.concat([hist_tabla, sc1, sc2], ignore_index=True))
    
    def calcular_metricas(hist_g, m, target_scaler, exog_vars_scaled, grupo, metricas_todos, exog_vars, exog_scaler):
        def smape(y_true, y_pred):
            denominator = np.abs(y_true) + np.abs(y_pred)
            # Use np.where instead of .where for numpy arrays
            denominator_safe = np.where(denominator != 0, denominator, 1)
            return 100 * np.mean(2 * np.abs(y_pred - y_true) / denominator_safe)
        
        # Use the last 7 rows or all if fewer than 7
        n_test = min(7, len(hist_g))
        test_hist = hist_g.tail(n_test).copy()
        
        # Prepare future dataframe for prediction
        future_test = test_hist[['ds'] + exog_vars_scaled]
        forecast_test = m.predict(future_test)
        
        # Inverse scale predictions
        y_true = target_scaler.inverse_transform(test_hist[['y_scaled']]).flatten()
        y_pred = target_scaler.inverse_transform(forecast_test[['yhat']]).flatten()
        
        # Calculate metrics
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))
        mae = mean_absolute_error(y_true, y_pred)
        smape_val = smape(y_true, y_pred)
        r2 = r2_score(y_true, y_pred)
        
        # Determine model quality
        if r2 >= 0.8 and smape_val < 20:
            quality = 'BUENO'
        elif r2 >= 0.5 or smape_val < 30:
            quality = 'ACEPTABLE'
        else:
            quality = 'POBRE'
        
        # Append metrics
        metricas_todos.append({
            'REGION_CATEGORIA_PRODUCTO': grupo,
            'RMSE': rmse,
            'MAE': mae,
            'SMAPE': smape_val,
            'R2': r2,
            'QUALITY': quality
        })
        
    # Calculate metrics
    calcular_metricas(hist_g, m, target_scaler, exog_vars_scaled, grupo, metricas_todos, exog_vars, exog_scaler)
# Out:
# Procesando grupos Prophet:   0%|          | 0/130 [00:00<?, ?it/s]2025-06-29 01:23:29,721 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:23:29,721 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:23:34,574 - DEBUG - Adding TBB (c:\Users\joey_\AppData\Local\Programs\Python\Python310\lib\site-packages\prophet\stan_model\cmdstan-2.33.1\stan\lib\stan_math\lib\tbb) to PATH
# 2025-06-29 01:23:34,689 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\_91nefxw.json
# 2025-06-29 01:23:34,705 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\ntsh5od7.json
# 2025-06-29 01:23:34,735 - DEBUG - idx 0
# 2025-06-29 01:23:34,739 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:23:34,744 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=54981', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\_91nefxw.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\ntsh5od7.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelb657cemf\\prophet_model-20250629012334.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:23:34 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:23:34,749 - INFO - Chain [1] start processing
# 2025-06-29 01:23:34,574 - DEBUG - Adding TBB (c:\Users\joey_\AppData\Local\Programs\Python\Python310\lib\site-packages\prophet\stan_model\cmdstan-2.33.1\stan\lib\stan_math\lib\tbb) to PATH
# 2025-06-29 01:23:34,689 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\_91nefxw.json
# 2025-06-29 01:23:34,705 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\ntsh5od7.json
# 2025-06-29 01:23:34,735 - DEBUG - idx 0
# 2025-06-29 01:23:34,739 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:23:34,744 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=54981', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\_91nefxw.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\ntsh5od7.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelb657cemf\\prophet_model-20250629012334.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:23:34 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:23:34,749 - INFO - Chain [1] start processing
# 01:23:42 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:23:42,094 - INFO - Chain [1] done processing
# Procesando grupos Prophet:   1%|          | 1/130 [00:14<30:51, 14.36s/it]2025-06-29 01:23:43,442 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 01:23:42 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:23:42,094 - INFO - Chain [1] done processing
# Procesando grupos Prophet:   1%|          | 1/130 [00:14<30:51, 14.36s/it]2025-06-29 01:23:43,442 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:23:43,994 - DEBUG - TBB already found in load path
# 2025-06-29 01:23:44,042 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\ajdu7cpk.json
# 2025-06-29 01:23:44,068 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\8uqa5k4w.json
# 2025-06-29 01:23:43,994 - DEBUG - TBB already found in load path
# 2025-06-29 01:23:44,042 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\ajdu7cpk.json
# 2025-06-29 01:23:44,068 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\8uqa5k4w.json
# 2025-06-29 01:23:44,084 - DEBUG - idx 0
# 2025-06-29 01:23:44,086 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:23:44,087 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=70712', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\ajdu7cpk.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\8uqa5k4w.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_model_g03mzmb\\prophet_model-20250629012344.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:23:44 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:23:44,088 - INFO - Chain [1] start processing
# 2025-06-29 01:23:44,084 - DEBUG - idx 0
# 2025-06-29 01:23:44,086 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:23:44,087 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=70712', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\ajdu7cpk.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\8uqa5k4w.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_model_g03mzmb\\prophet_model-20250629012344.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:23:44 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:23:44,088 - INFO - Chain [1] start processing
# 01:23:44 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:23:44,532 - INFO - Chain [1] done processing
# Procesando grupos Prophet:   2%|▏         | 2/130 [00:16<15:26,  7.24s/it]2025-06-29 01:23:45,623 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:23:46,041 - DEBUG - TBB already found in load path
# 2025-06-29 01:23:46,093 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\btefl7_j.json
# 2025-06-29 01:23:46,103 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\rq59zdu5.json
# 2025-06-29 01:23:46,108 - DEBUG - idx 0
# 2025-06-29 01:23:46,109 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:23:46,114 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=60386', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\btefl7_j.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\rq59zdu5.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_model_gml1spj\\prophet_model-20250629012346.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:23:46 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:23:46,116 - INFO - Chain [1] start processing
# 01:23:46 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:23:46,703 - INFO - Chain [1] done processing
# 01:23:44 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:23:44,532 - INFO - Chain [1] done processing
# Procesando grupos Prophet:   2%|▏         | 2/130 [00:16<15:26,  7.24s/it]2025-06-29 01:23:45,623 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:23:46,041 - DEBUG - TBB already found in load path
# 2025-06-29 01:23:46,093 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\btefl7_j.json
# 2025-06-29 01:23:46,103 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\rq59zdu5.json
# 2025-06-29 01:23:46,108 - DEBUG - idx 0
# 2025-06-29 01:23:46,109 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:23:46,114 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=60386', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\btefl7_j.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\rq59zdu5.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_model_gml1spj\\prophet_model-20250629012346.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:23:46 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:23:46,116 - INFO - Chain [1] start processing
# 01:23:46 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:23:46,703 - INFO - Chain [1] done processing
# Procesando grupos Prophet:   2%|▏         | 3/130 [00:18<10:06,  4.77s/it]2025-06-29 01:23:47,467 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:23:47,467 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:23:47,894 - DEBUG - TBB already found in load path
# 2025-06-29 01:23:47,894 - DEBUG - TBB already found in load path
# 2025-06-29 01:23:47,952 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\vvtdauu7.json
# 2025-06-29 01:23:47,962 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\tpxt7a8f.json
# 2025-06-29 01:23:47,952 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\vvtdauu7.json
# 2025-06-29 01:23:47,962 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\tpxt7a8f.json
# 2025-06-29 01:23:47,970 - DEBUG - idx 0
# 2025-06-29 01:23:47,972 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:23:47,978 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=14872', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\vvtdauu7.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\tpxt7a8f.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelvrba4_73\\prophet_model-20250629012347.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:23:47 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:23:47,980 - INFO - Chain [1] start processing
# 2025-06-29 01:23:47,970 - DEBUG - idx 0
# 2025-06-29 01:23:47,972 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:23:47,978 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=14872', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\vvtdauu7.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\tpxt7a8f.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelvrba4_73\\prophet_model-20250629012347.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:23:47 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:23:47,980 - INFO - Chain [1] start processing
# 01:23:48 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:23:48,479 - INFO - Chain [1] done processing
# 01:23:48 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:23:48,479 - INFO - Chain [1] done processing
# Procesando grupos Prophet:   3%|▎         | 4/130 [00:19<07:20,  3.49s/it]2025-06-29 01:23:49,016 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:23:49,016 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:23:49,586 - DEBUG - TBB already found in load path
# 2025-06-29 01:23:49,586 - DEBUG - TBB already found in load path
# 2025-06-29 01:23:49,651 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\o4m6atzk.json
# 2025-06-29 01:23:49,663 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\71rxwzl_.json
# 2025-06-29 01:23:49,651 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\o4m6atzk.json
# 2025-06-29 01:23:49,663 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\71rxwzl_.json
# 2025-06-29 01:23:49,684 - DEBUG - idx 0
# 2025-06-29 01:23:49,686 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:23:49,687 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=54433', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\o4m6atzk.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\71rxwzl_.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelii_r3ecw\\prophet_model-20250629012349.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:23:49 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:23:49,684 - DEBUG - idx 0
# 2025-06-29 01:23:49,686 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:23:49,687 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=54433', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\o4m6atzk.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\71rxwzl_.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelii_r3ecw\\prophet_model-20250629012349.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:23:49 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:23:49,691 - INFO - Chain [1] start processing
# 2025-06-29 01:23:49,691 - INFO - Chain [1] start processing
# 01:23:50 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:23:50,239 - INFO - Chain [1] done processing
# 01:23:50 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:23:50,239 - INFO - Chain [1] done processing
# Procesando grupos Prophet:   4%|▍         | 5/130 [00:21<05:55,  2.85s/it]2025-06-29 01:23:50,689 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:23:50,689 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:23:51,011 - DEBUG - TBB already found in load path
# 2025-06-29 01:23:51,011 - DEBUG - TBB already found in load path
# 2025-06-29 01:23:51,056 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\qa5wgxdg.json
# 2025-06-29 01:23:51,066 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\wg7tagsi.json
# 2025-06-29 01:23:51,056 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\qa5wgxdg.json
# 2025-06-29 01:23:51,066 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\wg7tagsi.json
# 2025-06-29 01:23:51,080 - DEBUG - idx 0
# 2025-06-29 01:23:51,082 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:23:51,084 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=34669', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\qa5wgxdg.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\wg7tagsi.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modeldm8o38pl\\prophet_model-20250629012351.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:23:51 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:23:51,086 - INFO - Chain [1] start processing
# 2025-06-29 01:23:51,080 - DEBUG - idx 0
# 2025-06-29 01:23:51,082 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:23:51,084 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=34669', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\qa5wgxdg.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\wg7tagsi.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modeldm8o38pl\\prophet_model-20250629012351.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:23:51 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:23:51,086 - INFO - Chain [1] start processing
# 01:23:51 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:23:51,719 - INFO - Chain [1] done processing
# 01:23:51 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:23:51,719 - INFO - Chain [1] done processing
# Procesando grupos Prophet:   5%|▍         | 6/130 [00:23<05:05,  2.46s/it]2025-06-29 01:23:52,439 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:23:52,439 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:23:52,774 - DEBUG - TBB already found in load path
# 2025-06-29 01:23:52,774 - DEBUG - TBB already found in load path
# 2025-06-29 01:23:52,816 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\s1uizukq.json
# 2025-06-29 01:23:52,826 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\5706cxf5.json
# 2025-06-29 01:23:52,816 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\s1uizukq.json
# 2025-06-29 01:23:52,826 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\5706cxf5.json
# 2025-06-29 01:23:52,831 - DEBUG - idx 0
# 2025-06-29 01:23:52,834 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:23:52,834 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=2872', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\s1uizukq.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\5706cxf5.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_model_w8q0_w_\\prophet_model-20250629012352.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:23:52 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:23:52,836 - INFO - Chain [1] start processing
# 2025-06-29 01:23:52,831 - DEBUG - idx 0
# 2025-06-29 01:23:52,834 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:23:52,834 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=2872', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\s1uizukq.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\5706cxf5.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_model_w8q0_w_\\prophet_model-20250629012352.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:23:52 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:23:52,836 - INFO - Chain [1] start processing
# 01:23:53 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:23:53,175 - INFO - Chain [1] done processing
# 01:23:53 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:23:53,175 - INFO - Chain [1] done processing
# Procesando grupos Prophet:   5%|▌         | 7/130 [00:24<04:10,  2.04s/it]2025-06-29 01:23:53,580 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:23:53,580 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:23:53,900 - DEBUG - TBB already found in load path
# 2025-06-29 01:23:53,900 - DEBUG - TBB already found in load path
# 2025-06-29 01:23:53,948 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\qjqa32e3.json
# 2025-06-29 01:23:53,957 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\lvnh9ec_.json
# 2025-06-29 01:23:53,948 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\qjqa32e3.json
# 2025-06-29 01:23:53,957 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\lvnh9ec_.json
# 2025-06-29 01:23:53,964 - DEBUG - idx 0
# 2025-06-29 01:23:53,968 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:23:53,971 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=12554', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\qjqa32e3.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\lvnh9ec_.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_model9vu9_kjy\\prophet_model-20250629012353.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:23:53 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:23:53,973 - INFO - Chain [1] start processing
# 2025-06-29 01:23:53,964 - DEBUG - idx 0
# 2025-06-29 01:23:53,968 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:23:53,971 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=12554', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\qjqa32e3.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\lvnh9ec_.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_model9vu9_kjy\\prophet_model-20250629012353.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:23:53 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:23:53,973 - INFO - Chain [1] start processing
# 01:23:54 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:23:54,389 - INFO - Chain [1] done processing
# 01:23:54 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:23:54,389 - INFO - Chain [1] done processing
# Procesando grupos Prophet:   6%|▌         | 8/130 [00:25<03:39,  1.80s/it]2025-06-29 01:23:54,876 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:23:54,876 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:23:55,210 - DEBUG - TBB already found in load path
# 2025-06-29 01:23:55,210 - DEBUG - TBB already found in load path
# 2025-06-29 01:23:55,261 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\iqxy1ohc.json
# 2025-06-29 01:23:55,270 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\qerx40fc.json
# 2025-06-29 01:23:55,261 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\iqxy1ohc.json
# 2025-06-29 01:23:55,270 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\qerx40fc.json
# 2025-06-29 01:23:55,275 - DEBUG - idx 0
# 2025-06-29 01:23:55,277 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:23:55,279 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=53447', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\iqxy1ohc.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\qerx40fc.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_model79vm_2cg\\prophet_model-20250629012355.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:23:55 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:23:55,281 - INFO - Chain [1] start processing
# 2025-06-29 01:23:55,275 - DEBUG - idx 0
# 2025-06-29 01:23:55,277 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:23:55,279 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=53447', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\iqxy1ohc.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\qerx40fc.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_model79vm_2cg\\prophet_model-20250629012355.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:23:55 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:23:55,281 - INFO - Chain [1] start processing
# 01:23:55 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:23:55,815 - INFO - Chain [1] done processing
# 01:23:55 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:23:55,815 - INFO - Chain [1] done processing
# Procesando grupos Prophet:   7%|▋         | 9/130 [00:28<04:20,  2.15s/it]2025-06-29 01:23:57,809 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# Procesando grupos Prophet:   7%|▋         | 9/130 [00:28<04:20,  2.15s/it]2025-06-29 01:23:57,809 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:23:58,279 - DEBUG - TBB already found in load path
# 2025-06-29 01:23:58,279 - DEBUG - TBB already found in load path
# 2025-06-29 01:23:58,519 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\83mkype2.json
# 2025-06-29 01:23:58,530 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\boeu222b.json
# 2025-06-29 01:23:58,519 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\83mkype2.json
# 2025-06-29 01:23:58,530 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\boeu222b.json
# 2025-06-29 01:23:58,535 - DEBUG - idx 0
# 2025-06-29 01:23:58,538 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:23:58,535 - DEBUG - idx 0
# 2025-06-29 01:23:58,538 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:23:58,543 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=80167', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\83mkype2.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\boeu222b.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelauclvwel\\prophet_model-20250629012358.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:23:58 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:23:58,545 - INFO - Chain [1] start processing
# 2025-06-29 01:23:58,543 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=80167', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\83mkype2.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\boeu222b.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelauclvwel\\prophet_model-20250629012358.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:23:58 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:23:58,545 - INFO - Chain [1] start processing
# 01:23:59 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:23:59,070 - INFO - Chain [1] done processing
# 01:23:59 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:23:59,070 - INFO - Chain [1] done processing
# Procesando grupos Prophet:   8%|▊         | 10/130 [00:30<04:06,  2.05s/it]2025-06-29 01:23:59,625 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:23:59,625 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:24:00,080 - DEBUG - TBB already found in load path
# 2025-06-29 01:24:00,080 - DEBUG - TBB already found in load path
# 2025-06-29 01:24:00,129 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\pcerqeat.json
# 2025-06-29 01:24:00,141 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\ljdg8yo5.json
# 2025-06-29 01:24:00,129 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\pcerqeat.json
# 2025-06-29 01:24:00,141 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\ljdg8yo5.json
# 2025-06-29 01:24:00,145 - DEBUG - idx 0
# 2025-06-29 01:24:00,148 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:24:00,150 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=31870', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\pcerqeat.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\ljdg8yo5.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_model1lkvke8w\\prophet_model-20250629012400.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:24:00 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:24:00,152 - INFO - Chain [1] start processing
# 2025-06-29 01:24:00,145 - DEBUG - idx 0
# 2025-06-29 01:24:00,148 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:24:00,150 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=31870', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\pcerqeat.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\ljdg8yo5.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_model1lkvke8w\\prophet_model-20250629012400.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:24:00 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:24:00,152 - INFO - Chain [1] start processing
# 01:24:00 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:24:00,671 - INFO - Chain [1] done processing
# 01:24:00 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:24:00,671 - INFO - Chain [1] done processing
# Procesando grupos Prophet:   8%|▊         | 11/130 [00:32<03:45,  1.89s/it]2025-06-29 01:24:01,147 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:24:01,147 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:24:01,532 - DEBUG - TBB already found in load path
# 2025-06-29 01:24:01,532 - DEBUG - TBB already found in load path
# 2025-06-29 01:24:01,581 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\biznz564.json
# 2025-06-29 01:24:01,591 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\6f3pxmtk.json
# 2025-06-29 01:24:01,581 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\biznz564.json
# 2025-06-29 01:24:01,591 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\6f3pxmtk.json
# 2025-06-29 01:24:01,596 - DEBUG - idx 0
# 2025-06-29 01:24:01,598 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:24:01,600 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=41666', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\biznz564.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\6f3pxmtk.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modeljyfeweq6\\prophet_model-20250629012401.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:24:01 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:24:01,601 - INFO - Chain [1] start processing
# 2025-06-29 01:24:01,596 - DEBUG - idx 0
# 2025-06-29 01:24:01,598 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:24:01,600 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=41666', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\biznz564.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\6f3pxmtk.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modeljyfeweq6\\prophet_model-20250629012401.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:24:01 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:24:01,601 - INFO - Chain [1] start processing
# 01:24:01 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:24:01,995 - INFO - Chain [1] done processing
# 01:24:01 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:24:01,995 - INFO - Chain [1] done processing
# Procesando grupos Prophet:   9%|▉         | 12/130 [00:33<03:20,  1.70s/it]2025-06-29 01:24:02,417 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:24:02,417 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:24:02,887 - DEBUG - TBB already found in load path
# 2025-06-29 01:24:02,945 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\51uenu42.json
# 2025-06-29 01:24:02,972 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\n54bfqbl.json
# 2025-06-29 01:24:02,976 - DEBUG - idx 0
# 2025-06-29 01:24:02,887 - DEBUG - TBB already found in load path
# 2025-06-29 01:24:02,945 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\51uenu42.json
# 2025-06-29 01:24:02,972 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\n54bfqbl.json
# 2025-06-29 01:24:02,976 - DEBUG - idx 0
# 2025-06-29 01:24:02,978 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:24:02,979 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=53519', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\51uenu42.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\n54bfqbl.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelnsh7gtg_\\prophet_model-20250629012402.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:24:02 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:24:02,980 - INFO - Chain [1] start processing
# 2025-06-29 01:24:02,978 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:24:02,979 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=53519', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\51uenu42.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\n54bfqbl.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelnsh7gtg_\\prophet_model-20250629012402.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:24:02 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:24:02,980 - INFO - Chain [1] start processing
# 01:24:03 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:24:03,578 - INFO - Chain [1] done processing
# 01:24:03 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:24:03,578 - INFO - Chain [1] done processing
# Procesando grupos Prophet:  10%|█         | 13/130 [00:34<03:14,  1.66s/it]2025-06-29 01:24:03,980 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:24:03,980 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:24:04,361 - DEBUG - TBB already found in load path
# 2025-06-29 01:24:04,361 - DEBUG - TBB already found in load path
# 2025-06-29 01:24:04,410 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\u3n9l9qe.json
# 2025-06-29 01:24:04,421 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\01lijrem.json
# 2025-06-29 01:24:04,433 - DEBUG - idx 0
# 2025-06-29 01:24:04,437 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:24:04,440 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=8349', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\u3n9l9qe.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\01lijrem.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelhzzbxvkc\\prophet_model-20250629012404.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:24:04 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:24:04,444 - INFO - Chain [1] start processing
# 2025-06-29 01:24:04,410 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\u3n9l9qe.json
# 2025-06-29 01:24:04,421 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\01lijrem.json
# 2025-06-29 01:24:04,433 - DEBUG - idx 0
# 2025-06-29 01:24:04,437 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:24:04,440 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=8349', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\u3n9l9qe.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\01lijrem.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelhzzbxvkc\\prophet_model-20250629012404.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:24:04 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:24:04,444 - INFO - Chain [1] start processing
# 01:24:04 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:24:04,894 - INFO - Chain [1] done processing
# 01:24:04 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:24:04,894 - INFO - Chain [1] done processing
# Procesando grupos Prophet:  11%|█         | 14/130 [00:36<03:06,  1.61s/it]2025-06-29 01:24:05,460 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:24:05,460 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:24:05,884 - DEBUG - TBB already found in load path
# 2025-06-29 01:24:05,884 - DEBUG - TBB already found in load path
# 2025-06-29 01:24:05,935 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\dh6sqyet.json
# 2025-06-29 01:24:05,947 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\i2o2x3rb.json
# 2025-06-29 01:24:05,962 - DEBUG - idx 0
# 2025-06-29 01:24:05,935 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\dh6sqyet.json
# 2025-06-29 01:24:05,947 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\i2o2x3rb.json
# 2025-06-29 01:24:05,962 - DEBUG - idx 0
# 2025-06-29 01:24:05,964 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:24:05,968 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=96789', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\dh6sqyet.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\i2o2x3rb.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelty_wf_pg\\prophet_model-20250629012405.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:24:05 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:24:05,970 - INFO - Chain [1] start processing
# 2025-06-29 01:24:05,964 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:24:05,968 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=96789', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\dh6sqyet.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\i2o2x3rb.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelty_wf_pg\\prophet_model-20250629012405.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:24:05 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:24:05,970 - INFO - Chain [1] start processing
# 01:24:06 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:24:06,371 - INFO - Chain [1] done processing
# 01:24:06 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:24:06,371 - INFO - Chain [1] done processing
# Procesando grupos Prophet:  12%|█▏        | 15/130 [00:37<02:56,  1.54s/it]2025-06-29 01:24:06,837 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:24:06,837 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:24:07,174 - DEBUG - TBB already found in load path
# 2025-06-29 01:24:07,174 - DEBUG - TBB already found in load path
# 2025-06-29 01:24:07,222 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\79hrzr9o.json
# 2025-06-29 01:24:07,232 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\rd92ahps.json
# 2025-06-29 01:24:07,237 - DEBUG - idx 0
# 2025-06-29 01:24:07,222 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\79hrzr9o.json
# 2025-06-29 01:24:07,232 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\rd92ahps.json
# 2025-06-29 01:24:07,237 - DEBUG - idx 0
# 2025-06-29 01:24:07,239 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:24:07,240 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=3108', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\79hrzr9o.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\rd92ahps.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_model5ncu1dvc\\prophet_model-20250629012407.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:24:07 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:24:07,243 - INFO - Chain [1] start processing
# 2025-06-29 01:24:07,239 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:24:07,240 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=3108', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\79hrzr9o.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\rd92ahps.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_model5ncu1dvc\\prophet_model-20250629012407.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:24:07 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:24:07,243 - INFO - Chain [1] start processing
# 01:24:07 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:24:07,757 - INFO - Chain [1] done processing
# 01:24:07 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:24:07,757 - INFO - Chain [1] done processing
# Procesando grupos Prophet:  12%|█▏        | 16/130 [00:39<02:49,  1.49s/it]2025-06-29 01:24:08,214 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:24:08,214 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:24:08,693 - DEBUG - TBB already found in load path
# 2025-06-29 01:24:08,693 - DEBUG - TBB already found in load path
# 2025-06-29 01:24:08,768 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\wapfywol.json
# 2025-06-29 01:24:08,779 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\j3aw8a51.json
# 2025-06-29 01:24:08,768 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\wapfywol.json
# 2025-06-29 01:24:08,779 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\j3aw8a51.json
# 2025-06-29 01:24:08,783 - DEBUG - idx 0
# 2025-06-29 01:24:08,804 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:24:08,783 - DEBUG - idx 0
# 2025-06-29 01:24:08,804 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:24:08,812 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=58418', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\wapfywol.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\j3aw8a51.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelde2916cu\\prophet_model-20250629012408.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:24:08 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:24:08,815 - INFO - Chain [1] start processing
# 2025-06-29 01:24:08,812 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=58418', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\wapfywol.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\j3aw8a51.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelde2916cu\\prophet_model-20250629012408.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:24:08 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:24:08,815 - INFO - Chain [1] start processing
# 01:24:09 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:24:09,254 - INFO - Chain [1] done processing
# 01:24:09 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:24:09,254 - INFO - Chain [1] done processing
# Procesando grupos Prophet:  13%|█▎        | 17/130 [00:40<02:48,  1.50s/it]2025-06-29 01:24:09,739 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:24:09,739 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:24:10,157 - DEBUG - TBB already found in load path
# 2025-06-29 01:24:10,205 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\eezm0338.json
# 2025-06-29 01:24:10,214 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\rmc0jb7p.json
# 2025-06-29 01:24:10,157 - DEBUG - TBB already found in load path
# 2025-06-29 01:24:10,205 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\eezm0338.json
# 2025-06-29 01:24:10,214 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\rmc0jb7p.json
# 2025-06-29 01:24:10,219 - DEBUG - idx 0
# 2025-06-29 01:24:10,222 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:24:10,224 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=10646', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\eezm0338.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\rmc0jb7p.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelikjaioeu\\prophet_model-20250629012410.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:24:10 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:24:10,226 - INFO - Chain [1] start processing
# 2025-06-29 01:24:10,219 - DEBUG - idx 0
# 2025-06-29 01:24:10,222 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:24:10,224 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=10646', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\eezm0338.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\rmc0jb7p.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelikjaioeu\\prophet_model-20250629012410.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:24:10 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:24:10,226 - INFO - Chain [1] start processing
# 01:24:10 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:24:10,799 - INFO - Chain [1] done processing
# 01:24:10 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:24:10,799 - INFO - Chain [1] done processing
# Procesando grupos Prophet:  14%|█▍        | 18/130 [00:42<02:50,  1.52s/it]2025-06-29 01:24:11,312 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:24:11,312 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:24:11,640 - DEBUG - TBB already found in load path
# 2025-06-29 01:24:11,640 - DEBUG - TBB already found in load path
# 2025-06-29 01:24:11,687 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\drizx3hn.json
# 2025-06-29 01:24:11,697 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\prjvbksn.json
# 2025-06-29 01:24:11,687 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\drizx3hn.json
# 2025-06-29 01:24:11,697 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\prjvbksn.json
# 2025-06-29 01:24:11,703 - DEBUG - idx 0
# 2025-06-29 01:24:11,705 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:24:11,708 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=29964', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\drizx3hn.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prjvbksn.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelbemakq_9\\prophet_model-20250629012411.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:24:11 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:24:11,710 - INFO - Chain [1] start processing
# 2025-06-29 01:24:11,703 - DEBUG - idx 0
# 2025-06-29 01:24:11,705 - DEBUG - running CmdStan, num_threads: None
# ...
# 01:28:33 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:28:33,694 - INFO - Chain [1] start processing
# 01:28:34 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:28:34,331 - INFO - Chain [1] done processing
# 01:28:34 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:28:34,331 - INFO - Chain [1] done processing
# Procesando grupos Prophet:  95%|█████████▌| 124/130 [05:05<00:10,  1.70s/it]2025-06-29 01:28:34,711 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:28:34,711 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:28:34,991 - DEBUG - TBB already found in load path
# 2025-06-29 01:28:34,991 - DEBUG - TBB already found in load path
# 2025-06-29 01:28:35,057 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\cbq76if5.json
# 2025-06-29 01:28:35,077 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\jq7tmtah.json
# 2025-06-29 01:28:35,091 - DEBUG - idx 0
# 2025-06-29 01:28:35,097 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:28:35,108 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=58888', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\cbq76if5.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\jq7tmtah.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_model94nw8gly\\prophet_model-20250629012835.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:28:35 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:28:35,145 - INFO - Chain [1] start processing
# 2025-06-29 01:28:35,057 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\cbq76if5.json
# 2025-06-29 01:28:35,077 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\jq7tmtah.json
# 2025-06-29 01:28:35,091 - DEBUG - idx 0
# 2025-06-29 01:28:35,097 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:28:35,108 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=58888', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\cbq76if5.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\jq7tmtah.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_model94nw8gly\\prophet_model-20250629012835.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:28:35 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:28:35,145 - INFO - Chain [1] start processing
# 01:28:35 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:28:35,805 - INFO - Chain [1] done processing
# 01:28:35 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:28:35,805 - INFO - Chain [1] done processing
# Procesando grupos Prophet:  96%|█████████▌| 125/130 [05:07<00:08,  1.67s/it]2025-06-29 01:28:36,352 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:28:36,352 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:28:36,797 - DEBUG - TBB already found in load path
# 2025-06-29 01:28:36,797 - DEBUG - TBB already found in load path
# 2025-06-29 01:28:36,863 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\ve57vg9a.json
# 2025-06-29 01:28:36,880 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\c21ch2td.json
# 2025-06-29 01:28:36,863 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\ve57vg9a.json
# 2025-06-29 01:28:36,880 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\c21ch2td.json
# 2025-06-29 01:28:36,884 - DEBUG - idx 0
# 2025-06-29 01:28:36,895 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:28:36,884 - DEBUG - idx 0
# 2025-06-29 01:28:36,895 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:28:36,899 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=17715', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\ve57vg9a.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\c21ch2td.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modeluh0l5nyz\\prophet_model-20250629012836.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 2025-06-29 01:28:36,899 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=17715', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\ve57vg9a.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\c21ch2td.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modeluh0l5nyz\\prophet_model-20250629012836.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:28:36 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:28:36,910 - INFO - Chain [1] start processing
# 01:28:36 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:28:36,910 - INFO - Chain [1] start processing
# 01:28:37 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:28:37,360 - INFO - Chain [1] done processing
# 01:28:37 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:28:37,360 - INFO - Chain [1] done processing
# Procesando grupos Prophet:  97%|█████████▋| 126/130 [05:09<00:06,  1.68s/it]2025-06-29 01:28:38,046 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:28:38,046 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:28:38,682 - DEBUG - TBB already found in load path
# 2025-06-29 01:28:38,682 - DEBUG - TBB already found in load path
# 2025-06-29 01:28:38,739 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\e5jjy4y3.json
# 2025-06-29 01:28:38,763 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\zeqef96b.json
# 2025-06-29 01:28:38,739 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\e5jjy4y3.json
# 2025-06-29 01:28:38,763 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\zeqef96b.json
# 2025-06-29 01:28:38,767 - DEBUG - idx 0
# 2025-06-29 01:28:38,779 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:28:38,785 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=14939', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\e5jjy4y3.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\zeqef96b.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelnkmus563\\prophet_model-20250629012838.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:28:38 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:28:38,789 - INFO - Chain [1] start processing
# 2025-06-29 01:28:38,767 - DEBUG - idx 0
# 2025-06-29 01:28:38,779 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:28:38,785 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=14939', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\e5jjy4y3.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\zeqef96b.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelnkmus563\\prophet_model-20250629012838.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:28:38 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:28:38,789 - INFO - Chain [1] start processing
# 01:28:39 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:28:39,574 - INFO - Chain [1] done processing
# 01:28:39 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:28:39,574 - INFO - Chain [1] done processing
# Procesando grupos Prophet:  98%|█████████▊| 127/130 [05:11<00:06,  2.03s/it]2025-06-29 01:28:40,888 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:28:40,888 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:28:41,308 - DEBUG - TBB already found in load path
# 2025-06-29 01:28:41,308 - DEBUG - TBB already found in load path
# 2025-06-29 01:28:41,368 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\xka0rtlz.json
# 2025-06-29 01:28:41,375 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\do8h931v.json
# 2025-06-29 01:28:41,379 - DEBUG - idx 0
# 2025-06-29 01:28:41,368 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\xka0rtlz.json
# 2025-06-29 01:28:41,375 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\do8h931v.json
# 2025-06-29 01:28:41,379 - DEBUG - idx 0
# 2025-06-29 01:28:41,380 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:28:41,381 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=27129', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\xka0rtlz.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\do8h931v.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_model6io2mquq\\prophet_model-20250629012841.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:28:41 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:28:41,380 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:28:41,381 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=27129', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\xka0rtlz.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\do8h931v.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_model6io2mquq\\prophet_model-20250629012841.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:28:41 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:28:41,385 - INFO - Chain [1] start processing
# 2025-06-29 01:28:41,385 - INFO - Chain [1] start processing
# 01:28:42 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:28:42,273 - INFO - Chain [1] done processing
# 01:28:42 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:28:42,273 - INFO - Chain [1] done processing
# Procesando grupos Prophet:  98%|█████████▊| 128/130 [05:13<00:03,  1.95s/it]2025-06-29 01:28:42,661 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:28:42,661 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:28:43,026 - DEBUG - TBB already found in load path
# 2025-06-29 01:28:43,026 - DEBUG - TBB already found in load path
# 2025-06-29 01:28:43,064 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\pasaemrw.json
# 2025-06-29 01:28:43,075 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\kfavegro.json
# 2025-06-29 01:28:43,079 - DEBUG - idx 0
# 2025-06-29 01:28:43,064 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\pasaemrw.json
# 2025-06-29 01:28:43,075 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\kfavegro.json
# 2025-06-29 01:28:43,079 - DEBUG - idx 0
# 2025-06-29 01:28:43,081 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:28:43,083 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=48333', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\pasaemrw.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\kfavegro.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_model80ok2kz0\\prophet_model-20250629012843.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:28:43 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:28:43,081 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:28:43,083 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=48333', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\pasaemrw.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\kfavegro.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_model80ok2kz0\\prophet_model-20250629012843.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:28:43 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:28:43,085 - INFO - Chain [1] start processing
# 2025-06-29 01:28:43,085 - INFO - Chain [1] start processing
# 01:28:48 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:28:48,461 - INFO - Chain [1] done processing
# 01:28:48 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:28:48,461 - INFO - Chain [1] done processing
# Procesando grupos Prophet:  99%|█████████▉| 129/130 [05:19<00:03,  3.24s/it]2025-06-29 01:28:48,887 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:28:48,887 - DEBUG - cmd: where.exe tbb.dll
# cwd: None
# 2025-06-29 01:28:49,305 - DEBUG - TBB already found in load path
# 2025-06-29 01:28:49,348 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\gcq9vyy9.json
# 2025-06-29 01:28:49,355 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\krtxa6f8.json
# 2025-06-29 01:28:49,305 - DEBUG - TBB already found in load path
# 2025-06-29 01:28:49,348 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\gcq9vyy9.json
# 2025-06-29 01:28:49,355 - DEBUG - input tempfile: C:\Users\joey_\AppData\Local\Temp\tmpy9crig4t\krtxa6f8.json
# 2025-06-29 01:28:49,363 - DEBUG - idx 0
# 2025-06-29 01:28:49,366 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:28:49,367 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=9146', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\gcq9vyy9.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\krtxa6f8.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelql918h7d\\prophet_model-20250629012849.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:28:49 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:28:49,368 - INFO - Chain [1] start processing
# 2025-06-29 01:28:49,363 - DEBUG - idx 0
# 2025-06-29 01:28:49,366 - DEBUG - running CmdStan, num_threads: None
# 2025-06-29 01:28:49,367 - DEBUG - CmdStan args: ['C:\\Users\\joey_\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\prophet\\stan_model\\prophet_model.bin', 'random', 'seed=9146', 'data', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\gcq9vyy9.json', 'init=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\krtxa6f8.json', 'output', 'file=C:\\Users\\joey_\\AppData\\Local\\Temp\\tmpy9crig4t\\prophet_modelql918h7d\\prophet_model-20250629012849.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:28:49 - cmdstanpy - INFO - Chain [1] start processing
# 2025-06-29 01:28:49,368 - INFO - Chain [1] start processing
# 01:28:49 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:28:49,953 - INFO - Chain [1] done processing
# 01:28:49 - cmdstanpy - INFO - Chain [1] done processing
# 2025-06-29 01:28:49,953 - INFO - Chain [1] done processing
# Procesando grupos Prophet: 100%|██████████| 130/130 [05:21<00:00,  2.47s/it]
# Procesando grupos Prophet: 100%|██████████| 130/130 [05:21<00:00,  2.47s/it]

# %%
print(f"Grupos procesados: {len(resultados_todos)}")
if len(resultados_todos) != len(grupos):
    logging.warning(f"Se esperaban {len(grupos)} grupos, pero se procesaron {len(resultados_todos)}")
# Out:
# Grupos procesados: 130

# %% [markdown]
# ## 5. Cálculo de Métricas por Grupo
#
# Para cada grupo, calculamos métricas de desempeño (RMSE, MAE, SMAPE, R2) en el histórico reciente y determinamos la calidad del modelo.

# %%
df_metricas = pd.DataFrame(metricas_todos)
print(f"Total de grupos con métricas: {len(df_metricas)}")
if len(df_metricas) != len(grupos):
    logging.warning(f"Se esperaban {len(grupos)} métricas, pero se generaron {len(df_metricas)}")

# Display metrics
display(df_metricas)
display(df_metricas.describe())
# Out:
# Total de grupos con métricas: 130
#                              REGION_CATEGORIA_PRODUCTO       RMSE        MAE  \
# 0              Antioquia-Jugo-Jugo Lima 2000mL x 12uds   2.572263   2.354717
# 1                 Antioquia-Gaseosa-Piña 600mL x 12uds   1.719893   1.518880
# 2                Antioquia-Agua-Agua Sin Gas 1L x 1uds   0.112490   0.093440
# 3           Antioquia-Jugo-Jugo Manzana 2000mL x 24uds  13.559341  10.685055
# 4                  Antioquia-Gaseosa-Uva 600mL x 24uds   3.283661   2.882006
# ..                                                 ...        ...        ...
# 125        Valle del Cauca-Agua-Agua con Gas 5L x 1uds   1.875240   1.524013
# 126         Valle del Cauca-Gaseosa-Piña 600mL x 12uds   0.789733   0.726848
# 127  Valle del Cauca-Bebida Energética-Energía Extr...   0.141058   0.112073
# 128                  Boyacá-Gaseosa-Piña 600mL x 12uds   0.000010   0.000008
# 129                    Meta-Gaseosa-Piña 600mL x 12uds   0.090365   0.059291
#
#          SMAPE        R2    QUALITY
# 0     2.851329  0.888603      BUENO
# 1     8.643584  0.538679  ACEPTABLE
# 2     2.599017  0.941358      BUENO
# 3     6.378865  0.868902      BUENO
# 4     5.806735  0.510225  ACEPTABLE
# ..         ...       ...        ...
# 125  14.142300  0.195414  ACEPTABLE
# 126   5.814025  0.915082      BUENO
# 127   3.473786  0.909005      BUENO
# 128   0.019594  1.000000      BUENO
# 129   4.416582  0.994966      BUENO
#
# [130 rows x 6 columns]
#              RMSE         MAE       SMAPE          R2
# count  130.000000  130.000000  130.000000  130.000000
# mean     2.063629    1.639999   12.868330    0.676229
# std      3.075820    2.442266    9.083117    0.290612
# min      0.000002    0.000002    0.000443   -0.779869
# 25%      0.141411    0.100874    6.112180    0.564435
# 50%      0.613346    0.489698   11.007667    0.758302
# 75%      2.893601    2.272756   16.551181    0.868423
# max     13.559341   10.787754   45.985436    1.000000

# %% [markdown]
# ## 7. Visualización Aleatoria del 10% de los Grupos
#
# Seleccionamos aleatoriamente el 10% de los grupos y graficamos para cada uno: evolución de variables exógenas, resultados de predicción, diferencias porcentuales mes a mes y tendencias.

# %%
# Seleccionar 10% de los grupos al azar para visualización
grupos_sample = random.sample(list(grupos), max(1, int(0.1 * len(grupos))))
print(f"Grupos seleccionados para visualización: {grupos_sample}")

# Create df_resultados from resultados_todos
df_resultados = pd.concat(resultados_todos, ignore_index=True) if resultados_todos else pd.DataFrame()

import re

def hex_to_rgba(hex_color, alpha=0.2):
    """Convert hex color string to rgba string with given alpha."""
    hex_color = hex_color.lstrip('#')
    if len(hex_color) == 6:
        r, g, b = tuple(int(hex_color[i:i+2], 16) for i in (0, 2, 4))
        return f'rgba({r},{g},{b},{alpha})'
    else:
        # fallback to gray if invalid
        return f'rgba(128,128,128,{alpha})'

for grupo in grupos_sample:
    df_g = df_resultados[df_resultados['REGION_CATEGORIA_PRODUCTO'] == grupo].copy()
    if df_g.empty:
        logging.warning(f"No hay datos para el grupo {grupo} en df_resultados")
        continue

    # Evolución de variables exógenas con Plotly
    fig_exog = sp.make_subplots(rows=len(exog_vars), cols=1, 
                                subplot_titles=[f'{grupo} - Evolución de {var}' for var in exog_vars],
                                shared_xaxes=True, vertical_spacing=0.1)

    for i, var in enumerate(exog_vars, start=1):
        hist_g = df_hist[df_hist['REGION_CATEGORIA_PRODUCTO'] == grupo].copy()
        fcst1_g = df_fcst1[df_fcst1['REGION_CATEGORIA_PRODUCTO'] == grupo].copy()
        fcst2_g = df_fcst2[df_fcst2['REGION_CATEGORIA_PRODUCTO'] == grupo].copy()
        
        # Add traces for each dataset
        fig_exog.add_trace(
            go.Scatter(x=hist_g['MES'], y=hist_g[var], mode='lines', name='Histórico', 
                        line=dict(color='black')),
            row=i, col=1
        )
        fig_exog.add_trace(
            go.Scatter(x=fcst1_g['MES'], y=fcst1_g[var], mode='lines', name='Escenario 1', 
                        line=dict(color='#8B7557')),  
            row=i, col=1
        )
        fig_exog.add_trace(
            go.Scatter(x=fcst2_g['MES'], y=fcst2_g[var], mode='lines', name='Escenario 2', 
                        line=dict(color='#1f77b4')),  
            row=i, col=1
        )

    # Update layout
    fig_exog.update_layout(
        height=300 * len(exog_vars), width=1000,
        title_text=f'Evolución de Variables Exógenas - {grupo}',
        showlegend=True,
                legend_title='Serie',
        legend=dict(
            orientation='h',
            yanchor='bottom',
            y=-0.3,
            x=0.5,
            xanchor='center')
    )
    fig_exog.update_xaxes(title_text='Fecha', row=len(exog_vars), col=1)
    for i, var in enumerate(exog_vars, start=1):
        fig_exog.update_yaxes(title_text=var, row=i, col=1)
    fig_exog.show()

    # Resultados de predicción con intervalos de confianza
    fig = go.Figure()
    color_list = ['#36332E', '#8B7557', '#57788B']
    for tipo, color in zip(['HISTÓRICO', 'ESCENARIO 1', 'ESCENARIO 2'], color_list):
        df_tipo = df_g[df_g['TIPO'] == tipo]
        # Add main prediction line
        fig.add_trace(go.Scatter(
            x=df_tipo['ds'], 
            y=df_tipo['M3_PRODUCTO'], 
            mode='lines', 
            name=tipo, 
            line=dict(color=color)
        ))
        # Add confidence intervals for forecast scenarios only
        if tipo in ['ESCENARIO 1', 'ESCENARIO 2']:
            # Upper bound
            fig.add_trace(go.Scatter(
                x=df_tipo['ds'], 
                y=df_tipo['IC_95_UPPER'], 
                mode='lines', 
                line=dict(width=0), 
                showlegend=False, 
                hoverinfo='skip'
            ))
            # Lower bound with fill to upper bound
            fig.add_trace(go.Scatter(
                x=df_tipo['ds'], 
                y=df_tipo['IC_95_LOWER'], 
                mode='lines', 
                line=dict(width=0), 
                fill='tonexty', 
                fillcolor=hex_to_rgba(color, 0.2),  # Proper rgba color
                showlegend=False, 
                hoverinfo='skip'
            ))

    fig.update_layout(
        title=f'Predicción de Cantidades Vendidas - {grupo}', 
        xaxis_title='Fecha', 
        yaxis_title='Cantidad Vendida (m3)', 
        legend_title='Serie',
        legend=dict(
            orientation='h',
            yanchor='bottom',
            y=-0.35,
            x=0.5,
            xanchor='center'),
        width=1000, 
        height=400
    )
    fig.show()

    # Diferencias porcentuales
    fig = go.Figure()
    for tipo, color in zip(['HISTÓRICO', 'ESCENARIO 1', 'ESCENARIO 2'], ['#36332E', '#8B7557', '#57788B']):
        df_tipo = df_g[df_g['TIPO'] == tipo]
        fig.add_trace(go.Bar(x=df_tipo['ds'], y=df_tipo['DIF_PCT'], name=tipo, marker_color=color))
    fig.update_layout(
        title=f'Diferencia porcentual mes a mes - {grupo}', 
        xaxis_title='Fecha', 
        yaxis_title='% Dif.',
        legend_title='Serie',
        legend=dict(
            orientation='h',
            yanchor='bottom',
            y=-0.35,
            x=0.5,
            xanchor='center'), 
        width=1000, 
        height=400
    )
    fig.show()
# Out:
# Grupos seleccionados para visualización: ['Santander-Gaseosa-Piña 600mL x 12uds', 'Bolívar-Bebida Energética-Power Up 250mL x 6uds', 'Boyacá-Bebida Energética-Power Up 250mL x 6uds', 'Santander-Agua-Agua con Gas 500mL x 6uds', 'Atlántico-Gaseosa-Uva 600mL x 24uds', 'Antioquia-Agua-Agua con Gas 5L x 1uds', 'Meta-Agua-Agua Sin Gas 5L x 12uds', 'Valle del Cauca-Bebida Energética-Power Up 250mL x 4uds', 'Meta-Bebida Energética-Energía Extrema 500mL x 6uds', 'Antioquia-Bebida de Té-Té Verde 300mL x 1uds', 'Boyacá-Gaseosa-Piña 600mL x 12uds', 'Tolima-Agua-Agua Sin Gas 1L x 1uds', 'Cundinamarca-Gaseosa-Piña 600mL x 12uds']

# %% [markdown]
# ## 6. Consolidación y Exportación de Resultados a Snowflake
#
# Unificamos los resultados y métricas de todos los grupos en dataframes finales y exportamos a Snowflake usando COPY INTO e INSERT INTO.

# %%
# Consolidate results
df_resultados = pd.concat(resultados_todos, ignore_index=True) if resultados_todos else pd.DataFrame()

# Add split columns
split_cols = df_resultados['REGION_CATEGORIA_PRODUCTO'].str.split('-', n=2, expand=True)
df_resultados['REGION'] = split_cols[0]
df_resultados['CATEGORIA'] = split_cols[1]
df_resultados['PRODUCTO'] = split_cols[2]
df_resultados = df_resultados.rename(columns={'ds': 'FECHA'})

# Validate row count
n_hist = len(df_hist)
n_fcst1 = len(df_fcst1)
n_fcst2 = len(df_fcst2)
suma_esperada = n_hist + n_fcst1 + n_fcst2
suma_real = len(df_resultados)
print(f"Filas esperadas (histórico + esc1 + esc2): {suma_esperada}")
print(f"Filas reales en df_resultados: {suma_real}")
if suma_esperada == suma_real:
    print("✔️ La suma de filas es correcta.")
else:
    logging.warning(f"❌ Diferencia detectada: esperadas {suma_esperada}, reales {suma_real}")
# Out:
# Filas esperadas (histórico + esc1 + esc2): 6823
# Filas reales en df_resultados: 6823
# ✔️ La suma de filas es correcta.

# %% [markdown]
# ## 6.1 Envío de datos a Snowflake

# %%
# Exportar a Snowflake (ajustar según tu función de exportación)
def export_prophet_results_to_snowflake(df_resultados, df_metricas):
    conn = get_snowflake_connection()
    cursor = conn.cursor()
    timestamp_str = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    temp_csv_path = 'temp_prophet_resultados.csv'
    temp_metrics_path = 'temp_prophet_metrics.csv'
    try:
        # Crear tablas si no existen
        cursor.execute("""
            CREATE TABLE IF NOT EXISTS PROPHET_M3_RESULTADOS (
                ID INTEGER AUTOINCREMENT,
                TIMESTAMP_COL TIMESTAMP_NTZ,
                REGION_CATEGORIA_PRODUCTO VARCHAR(300),
                REGION VARCHAR(100),
                CATEGORIA VARCHAR(100),
                PRODUCTO VARCHAR(100),
                FECHA DATE,
                TIPO VARCHAR(30),
                M3_PRODUCTO FLOAT,
                IC_95_LOWER FLOAT,
                IC_95_UPPER FLOAT,
                DIF_PCT FLOAT
            )
        """)
        cursor.execute("""
            CREATE TABLE IF NOT EXISTS PROPHET_M3_METRICS (
                ID INTEGER AUTOINCREMENT,
                TIMESTAMP_COL TIMESTAMP_NTZ,
                REGION_CATEGORIA_PRODUCTO VARCHAR(300),
                RMSE FLOAT,
                MAE FLOAT,
                SMAPE FLOAT,
                R2 FLOAT,
                QUALITY VARCHAR(20)
            )
        """)
        # Exportar resultados
        df_resultados['TIMESTAMP_COL'] = timestamp_str
        cols_result = ['TIMESTAMP_COL', 'REGION_CATEGORIA_PRODUCTO', 'REGION', 'CATEGORIA', 'PRODUCTO', 'FECHA', 'TIPO', 'M3_PRODUCTO', 'IC_95_LOWER', 'IC_95_UPPER', 'DIF_PCT']
        df_resultados[cols_result].to_csv(temp_csv_path, index=False, header=False, encoding='utf-8')
        cursor.execute(f"PUT file://{temp_csv_path} @~/prophet_stage AUTO_COMPRESS = TRUE OVERWRITE = TRUE")
        cursor.execute("TRUNCATE TABLE PROPHET_M3_RESULTADOS")
        cursor.execute(f"""
            COPY INTO PROPHET_M3_RESULTADOS (TIMESTAMP_COL, REGION_CATEGORIA_PRODUCTO, REGION, CATEGORIA, PRODUCTO, FECHA, TIPO, M3_PRODUCTO, IC_95_LOWER, IC_95_UPPER, DIF_PCT)
            FROM @~/prophet_stage/{temp_csv_path}.gz
            FILE_FORMAT = (TYPE = 'CSV' FIELD_DELIMITER = ',' SKIP_HEADER = 0 FIELD_OPTIONALLY_ENCLOSED_BY = '"')
        """)
        # Exportar métricas
        df_metricas['TIMESTAMP_COL'] = timestamp_str
        cols_metrics = ['TIMESTAMP_COL', 'REGION_CATEGORIA_PRODUCTO', 'RMSE', 'MAE', 'SMAPE', 'R2', 'QUALITY']
        df_metricas[cols_metrics].to_csv(temp_metrics_path, index=False, header=False, encoding='utf-8')
        cursor.execute(f"PUT file://{temp_metrics_path} @~/prophet_stage AUTO_COMPRESS = TRUE OVERWRITE = TRUE")
        cursor.execute(f"""
            COPY INTO PROPHET_M3_METRICS (TIMESTAMP_COL, REGION_CATEGORIA_PRODUCTO, RMSE, MAE, SMAPE, R2, QUALITY)
            FROM @~/prophet_stage/{temp_metrics_path}.gz
            FILE_FORMAT = (TYPE = 'CSV' FIELD_DELIMITER = ',' SKIP_HEADER = 0 FIELD_OPTIONALLY_ENCLOSED_BY = '"')
        """)
        conn.commit()
        print('Exportación a Snowflake completada.')
    except Exception as e:
        conn.rollback()
        print(f'Error al exportar a Snowflake: {e}')
    finally:
        cursor.close()
        conn.close()
        import os
        if os.path.exists(temp_csv_path):
            os.remove(temp_csv_path)
        if os.path.exists(temp_metrics_path):
            os.remove(temp_metrics_path)

# Llamar exportación
export_prophet_results_to_snowflake(df_resultados, df_metricas)

def print_snowflake_counts():
    try:
        conn = get_snowflake_connection()
        cursor = conn.cursor()
        cursor.execute('SELECT COUNT(*) FROM PROPHET_M3_RESULTADOS')
        count_resultados = cursor.fetchone()[0]
        print(f'Número de Registros: {count_resultados}')
        cursor.execute('SELECT COUNT(*) FROM PROPHET_M3_METRICS')
        count_metrics = cursor.fetchone()[0]
        print(f'Número de Registros: {count_metrics}')
        cursor.close()
        conn.close()
    except Exception as e:
        print(f'Error al consultar tablas en Snowflake: {e}')

# Llamar solo una vez para evitar duplicados
print_snowflake_counts()
# Out:
# 2025-06-29 01:29:05,161 - INFO - Snowflake Connector for Python Version: 3.15.0, Python Version: 3.10.11, Platform: Windows-10-10.0.19045-SP0
# 2025-06-29 01:29:05,163 - INFO - Connecting to GLOBAL Snowflake domain
# 2025-06-29 01:29:05,163 - INFO - Connecting to GLOBAL Snowflake domain
# 2025-06-29 01:29:06,147 - INFO - Conexión a Snowflake exitosa
# 2025-06-29 01:29:06,147 - INFO - Conexión a Snowflake exitosa
# Exportación a Snowflake completada.
# 2025-06-29 01:29:13,531 - INFO - Snowflake Connector for Python Version: 3.15.0, Python Version: 3.10.11, Platform: Windows-10-10.0.19045-SP0
# 2025-06-29 01:29:13,533 - INFO - Connecting to GLOBAL Snowflake domain
# 2025-06-29 01:29:13,533 - INFO - Connecting to GLOBAL Snowflake domain
# 2025-06-29 01:29:14,159 - INFO - Conexión a Snowflake exitosa
# 2025-06-29 01:29:14,159 - INFO - Conexión a Snowflake exitosa
# Número de Registros: 6823
# Número de Registros: 390
# Número de Registros: 390

# %% [markdown]
# ## 7. Notificación a Discord

# %%
import requests
import datetime

def send_discord_message(message: str, success: bool = True) -> None:
    """Envía un mensaje a Discord con el estado de la exportación."""
    try:
        DISCORD_WEBHOOK_URL = "xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"  # <-- Cambia esto por tu webhook real
        timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        color = 0x00FF00 if success else 0xFF0000
        emoji = "✅" if success else "❌"
        payload = {
            "embeds": [{
                "title": f"{emoji} Exportación Prophet a Snowflake",
                "description": message,
                "color": color,
                "fields": [
                    {"name": "Timestamp", "value": timestamp, "inline": True}
                ],
                "footer": {"text": "Sistema de Monitoreo ML"}
            }]
        }
        response = requests.post(DISCORD_WEBHOOK_URL, json=payload)
        if response.status_code == 204:
            print("Mensaje enviado a Discord.")
        else:
            print(f"Error al enviar mensaje a Discord: {response.text}")
    except Exception as e:
        print(f"Error al enviar mensaje a Discord: {e}")

# Consulta los conteos en Snowflake y envía mensaje a Discord
try:
    conn = get_snowflake_connection()
    cursor = conn.cursor()
    cursor.execute('SELECT COUNT(*) FROM PROPHET_M3_RESULTADOS')
    count_resultados = cursor.fetchone()[0]
    cursor.execute('SELECT COUNT(*) FROM PROPHET_M3_METRICS')
    count_metrics = cursor.fetchone()[0]
    cursor.close()
    conn.close()
    enviados_resultados = len(df_resultados)
    enviados_metricas = len(df_metricas)
    mensaje = (
        f"Datos enviados a Snowflake:\n"
        f"- Resultados: {enviados_resultados}\n"
        f"- Métricas: {enviados_metricas}\n\n"
        f"Conteo actual en tablas Snowflake:\n"
        f"- PROPHET_M3_RESULTADOS: {count_resultados}\n"
        f"- PROPHET_M3_METRICS: {count_metrics}"
    )
    send_discord_message(mensaje, success=True)
except Exception as e:
    send_discord_message(f"Error al consultar o enviar a Discord: {e}", success=False)
# Out:
# 2025-06-29 01:29:15,173 - INFO - Snowflake Connector for Python Version: 3.15.0, Python Version: 3.10.11, Platform: Windows-10-10.0.19045-SP0
# 2025-06-29 01:29:15,175 - INFO - Connecting to GLOBAL Snowflake domain
# 2025-06-29 01:29:15,175 - INFO - Connecting to GLOBAL Snowflake domain
# 2025-06-29 01:29:15,829 - INFO - Conexión a Snowflake exitosa
# 2025-06-29 01:29:15,829 - INFO - Conexión a Snowflake exitosa
# Mensaje enviado a Discord.
