# %%
import pandas as pd

url = "https://raw.githubusercontent.com/ringoquimico/Portfolio/refs/heads/main/Data%20Sources/call_center_data.csv"

df = pd.read_csv(url)
sorted_df = df.sort_values(by='resolution_time_min', ascending=False).head(5)
sorted_df
# Out:
#           case_id        date start_of_week start_of_month  \
# 2511   CASE-21751  2023-02-22    2023-02-19     2023-02-01
# 13182  CASE-28382  2024-07-03    2024-06-30     2024-07-01
# 4458   CASE-19929  2023-03-31    2023-03-26     2023-03-01
# 5901   CASE-16383  2023-09-08    2023-09-03     2023-09-01
# 12189  CASE-25163  2022-09-16    2022-09-11     2022-09-01
#
#                                      translated_comments sentiment  \
# 2511       The chatbot couldn’t handle my payment issue.  negative
# 13182   The chatbot gave me wrong info about my account.  negative
# 4458   Phone support was slow and didn’t fix my card ...  negative
# 5901       Email support didn’t bother to read my email.  negative
# 12189  The chatbot misunderstood my loan inquiry comp...  negative
#
#        sentiment_rate channel  resolution_time_min  csat_rating_received  \
# 2511                1   email                 9756                     2
# 13182               1   email                 9371                     2
# 4458                2   email                 9338                     2
# 5901                2   email                 9123                     2
# 12189               2   email                 9093                     2
#
#       classification  resolved_in_sla  first_touch_resolution  \
# 2511       DETRACTOR                0                       0
# 13182      DETRACTOR                0                       0
# 4458       DETRACTOR                0                       0
# 5901       DETRACTOR                0                       0
# 12189      DETRACTOR                0                       0
#
#                             group_name_history  groups  total_groups  \
# 2511   Grupo A,Grupo J,Grupo E,Grupo H,Grupo D       5             5
# 13182  Grupo C,Grupo F,Grupo I,Grupo G,Grupo I       4             5
# 4458   Grupo J,Grupo B,Grupo F,Grupo J,Grupo B       3             5
# 5901   Grupo J,Grupo I,Grupo E,Grupo F,Grupo D       5             5
# 12189  Grupo E,Grupo I,Grupo E,Grupo J,Grupo I       3             5
#
#       csat_rated_group_name issue_classification
# 2511                Grupo D       Payment Issues
# 13182               Grupo I      Balance Inquiry
# 4458                Grupo B    Transaction Error
# 5901                Grupo D    Transaction Error
# 12189               Grupo I       Login Problems
